# %% [markdown]
# <a href="https://colab.research.google.com/github/RohitJaiswal01/Customer-purchase-and-customer-segmentation-Analysis/blob/main/Customer_Purchase_Behavior_Applied_Statistics_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Customer Purchase Behavior Analysis using Descriptive Statistics

# %% [markdown]
# **Project Type** - Customer Purchase Behavior Analysis
#
# **Contribution** - Individual
#
#  **Name** - Rohit Jaiswal
#
#  **Cohort - Chandrayaan**

# %% [markdown]
# ##Problem Statement

# %% [markdown]
# 🔍 **Problem Statement**:
#
# Welcome to the Probability and Statistics project! 📊🔍 In this exciting journey, you'll get the chance to apply the concepts you've learned in probability theory and statistics to analyze a real-world dataset. This project is your opportunity to dive deep into the world of data analysis and gain practical experience with the tools and techniques you've been learning. 🚀
#
# 🎯 **Objective**:
#
# Your mission is to analyze the provided dataset containing customer information and purchasing behavior to make informed decisions. Your goal is to identify patterns, trends, and correlations that will help your company optimize its marketing efforts and increase offer acceptance rates. 🎉

# %% [markdown]
# ##About the Dataset

# %% [markdown]
# Here's the link to the [dataset](https://docs.google.com/spreadsheets/d/12ln9iTNcVNOMYi_AU-OczKpa_KIP8XyVbsjk81Na8Yk/edit?usp=sharing)
#
#
# This data was gathered during last year's campaign.
# Data description is as follows;
#
# 1. Response (target) - 1 if customer accepted the offer in the last campaign, 0 otherwise
# 1. ID - Unique ID of each customer
# 1. Year_Birth - Age of the customer
# 1. Complain - 1 if the customer complained in the last 2 years
# 1. Dt_Customer - date of customer's enrollment with the company
# 1. Education - customer's level of education
# 1. Marital - customer's marital status
# 1. Kidhome - number of small children in customer's household
# 1. Teenhome - number of teenagers in customer's household
# 1. Income - customer's yearly household income
# 1. MntFishProducts - the amount spent on fish products in the last 2 years
# 1. MntMeatProducts - the amount spent on meat products in the last 2 years
# 1. MntFruits - the amount spent on fruits products in the last 2 years
# 1. MntSweetProducts - amount spent on sweet products in the last 2 years
# 1. MntWines - the amount spent on wine products in the last 2 years
# 1. MntGoldProds - the amount spent on gold products in the last 2 years
# 1. NumDealsPurchases - number of purchases made with discount
# 1. NumCatalogPurchases - number of purchases made using catalog (buying goods to be shipped through the mail)
# 1. NumStorePurchases - number of purchases made directly in stores
# 1. NumWebPurchases - number of purchases made through the company's website
# 1. NumWebVisitsMonth - number of visits to company's website in the last month
# 1. Recency - number of days since the last purchase

# %% [markdown]
# ##Task 1 - Basic CleanUp
#
# - **Clean and preprocess the dataset (handling missing values, data types, etc.).**
#
# - **Analyze the distribution of customer demographics (age, education, marital status) using descriptive statistics and visualizations.**

# %% [markdown]
# **Deliverables**:
#
# - **Cleaned and Preprocessed Dataset**:
#
#   Provide a detailed report on the steps taken to handle missing values, including imputation methods used if applicable.
#   Document the process of ensuring consistent data types for each variable, addressing any inconsistencies.
#
# - **Summary of Basic Statistics**:
#
#   Present calculated statistics such as mean, median, variance, and standard deviation for each relevant numerical variable.
#   Include a concise table or summary showcasing these measures for easy reference.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load Dataset
# Loading the repository files from the github to collab
# !git clone https://github.com/RohitJaiswal01/Customer-purchase-and-customer-segmentation-Analysis.git

# Giving a path to the file
path = "/content/Customer-purchase-and-customer-segmentation-Analysis/Superstore Marketing Data.csv"
# Out:
# fatal: destination path 'Customer-purchase-and-customer-segmentation-Analysis' already exists and is not an empty directory.

# %%
Data_Superstore = pd.read_csv(path)

# %%
Data_Superstore.head()
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3    ########        0        10  ...                0                 0
# 4    ########        0         6  ...               11                 0
#
# ...

# %%
#Shape of dataset
Data_Superstore.shape
# Out:
# (2240, 22)

# %%
#Information about Dataset
Data_Superstore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2216 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %%
# Some wrong data in the Dt_Customer column
Data_Superstore["Dt_Customer"].value_counts()
# Out:
# Dt_Customer
# ########      916
# 8/31/2012      12
# 2/14/2013      11
# 5/22/2014      10
# 8/20/2013      10
#              ...
# 9/21/2013       1
# 11/14/2012      1
# 4/14/2013       1
# 10/19/2012      1
# 5/25/2013       1
# Name: count, Length: 401, dtype: int64

# %%
Data_Superstore["Dt_Customer"]
# Out:
# 0        6/16/2014
# 1        6/15/2014
# 2        5/13/2014
# 3         ########
# 4         ########
#            ...
# 2235      ########
# 2236     1/22/2013
# 2237      ########
# 2238    11/29/2012
# 2239      ########
# Name: Dt_Customer, Length: 2240, dtype: object

# %%
# Getting the latest purchase date for the dataset
Data_Superstore["Dt_Customer"].max()
# Out:
# '9/30/2013'

# %%
# Dropping Dt_Customer column
Data_Superstore.drop("Dt_Customer", axis = 1, inplace = True)

# %%
# Extracting the latest year
import datetime as dt
latest_date = dt.datetime(2013,12,31)
latest_date_year = latest_date.year
print(latest_date_year)
# Out:
# 2013

# %%
# Making a new column named as Age
Data_Superstore["Age"] = latest_date_year - Data_Superstore["Year_Birth"]
Data_Superstore[["Age"]]
# Out:
#       Age
# 0      43
# 1      52
# 2      55
# 3      46
# 4      24
# ...   ...
# 2235   37
# 2236   36
# 2237   37
# 2238   35
# 2239   44
#
# [2240 rows x 1 columns]

# %%
# Checking unique values in columns
Data_Superstore.nunique()
# Out:
# Id                     2240
# Year_Birth               59
# Education                 5
# Marital_Status            8
# Income                 1974
# Kidhome                   3
# Teenhome                  3
# Recency                 100
# MntWines                776
# MntFruits               158
# MntMeatProducts         558
# MntFishProducts         182
# MntSweetProducts        177
# MntGoldProds            213
# NumDealsPurchases        15
# NumWebPurchases          15
# NumCatalogPurchases      14
# NumStorePurchases        14
# NumWebVisitsMonth        16
# Response                  2
# Complain                  2
# Age                      59
# dtype: int64

# %%
#Find missing Values
missing_values = Data_Superstore.isnull().sum()
missing_values
# Out:
# Id                      0
# Year_Birth              0
# Education               0
# Marital_Status          0
# Income                 24
# Kidhome                 0
# Teenhome                0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# Response                0
# Complain                0
# Age                     0
# dtype: int64

# %%
# check for duplicate values in dataset
Data_Superstore.duplicated().sum()
# Out:
# 0

# %%
# Drop missing values in Income column
Data_Superstore.dropna(subset = ["Income"], inplace = True)

# %%
# Updated null value count
Data_Superstore.isnull().sum()
# Out:
# Id                     0
# Year_Birth             0
# Education              0
# Marital_Status         0
# Income                 0
# Kidhome                0
# Teenhome               0
# Recency                0
# MntWines               0
# MntFruits              0
# MntMeatProducts        0
# MntFishProducts        0
# MntSweetProducts       0
# MntGoldProds           0
# NumDealsPurchases      0
# NumWebPurchases        0
# NumCatalogPurchases    0
# NumStorePurchases      0
# NumWebVisitsMonth      0
# Response               0
# Complain               0
# Age                    0
# dtype: int64

# %%
# Display the summary statistics DataFrame
Data_Superstore.describe()
# Out:
#                  Id   Year_Birth         Income      Kidhome     Teenhome  \
# count   2216.000000  2216.000000    2216.000000  2216.000000  2216.000000
# mean    5588.353339  1968.820397   52247.251354     0.441787     0.505415
# std     3249.376275    11.985554   25173.076661     0.536896     0.544181
# min        0.000000  1893.000000    1730.000000     0.000000     0.000000
# 25%     2814.750000  1959.000000   35303.000000     0.000000     0.000000
# 50%     5458.500000  1970.000000   51381.500000     0.000000     0.000000
# 75%     8421.750000  1977.000000   68522.000000     1.000000     1.000000
# max    11191.000000  1996.000000  666666.000000     2.000000     2.000000
#
#            Recency     MntWines    MntFruits  MntMeatProducts  \
# count  2216.000000  2216.000000  2216.000000      2216.000000
# mean     49.012635   305.091606    26.356047       166.995939
# std      28.948352   337.327920    39.793917       224.283273
# ...

# %%
#showing distribution of age
plt.figure(figsize=(8, 4))
sns.histplot(Data_Superstore['Age'], bins=30, kde=True)
plt.title('Age Distribution')
plt.xlabel('Year of Birth')
plt.show()

# %%
#showing distribution of Education

plt.figure(figsize=(8, 6))
sns.countplot(x='Education', data=Data_Superstore)
plt.title('Distribution of Education')
plt.show()

# %%
#showing distribution of income

plt.figure(figsize=(8, 6))
sns.histplot(Data_Superstore['Income'], bins=30, kde=True)
plt.title('Distribution of Income')
plt.xlabel('Income')
plt.show()

# %%
#showing distribution of marital status
plt.figure(figsize=(8, 6))
sns.countplot(x='Marital_Status', data=Data_Superstore)
plt.title('Distribution of Marital Status')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##Task 2 - Descriptive Statistics 📊
#
# - **Calculate measures of central tendency (mean, median, mode) and measures of dispersion (variance, standard deviation) for key variables. Identify and handle outliers if necessary.**

# %% [markdown]
# **Deliverables**:
#
# - **Descriptive statistics that reveal the central tendencies, variations, and potential outliers in the dataset.**:

# %% [markdown]
# ### Calculate measures of central tendency (mean, median, mode)

# %%
# Lets first calculate measures of central tendency (mean, median, mode)
# 1 : Mean
key_variable = ['Income','Age','Recency','MntWines','MntFruits','MntMeatProducts','MntFishProducts','NumDealsPurchases','MntGoldProds','NumWebPurchases','NumWebVisitsMonth']
mean = Data_Superstore[key_variable].mean()
print(f'Mean of selected variables of datasets are:\n {mean}')
# Out:
# Mean of selected variables of datasets are:
#  Income               52247.251354
# Age                     44.179603
# Recency                 49.012635
# MntWines               305.091606
# MntFruits               26.356047
# MntMeatProducts        166.995939
# MntFishProducts         37.637635
# NumDealsPurchases        2.323556
# MntGoldProds            43.965253
# NumWebPurchases          4.085289
# NumWebVisitsMonth        5.319043
# dtype: float64

# %%
# 2 : Median
key_variable = ['Income','Age','Recency','Kidhome','Teenhome','MntWines','MntFruits','MntMeatProducts','MntFishProducts','NumDealsPurchases','NumWebPurchases','NumWebVisitsMonth']
median =Data_Superstore[key_variable].median()
print(f'Median of key variables of datasets are:\n {median}')
# Out:
# Median of key variables of datasets are:
#  Income               51381.5
# Age                     43.0
# Recency                 49.0
# Kidhome                  0.0
# Teenhome                 0.0
# MntWines               174.5
# MntFruits                8.0
# MntMeatProducts         68.0
# MntFishProducts         12.0
# NumDealsPurchases        2.0
# NumWebPurchases          4.0
# NumWebVisitsMonth        6.0
# dtype: float64

# %%
# 3 : Mode
key_variable = ['Income','Age','Recency','Kidhome','Teenhome','MntWines','MntFruits','MntMeatProducts','MntFishProducts','NumDealsPurchases','NumWebPurchases','NumWebVisitsMonth']
mode =Data_Superstore[key_variable].mode()
print(f'Mode of key variables of datasets are:\n {mode}')
# Out:
# Mode of key variables of datasets are:
#     Income  Age  Recency  Kidhome  Teenhome  MntWines  MntFruits  \
# 0  7500.0   37       56        0         0         2          0
#
#    MntMeatProducts  MntFishProducts  NumDealsPurchases  NumWebPurchases  \
# 0                7                0                  1                2
#
#    NumWebVisitsMonth
# 0                  7

# %% [markdown]
# ### Measures of dispersion (variance, standard deviation) for key variables:

# %%
# 4 : Variance
key_variable = ['Income','Age','Recency','Kidhome','Teenhome','MntWines','MntFruits','MntMeatProducts','MntFishProducts','NumDealsPurchases','NumWebPurchases','NumWebVisitsMonth']
variance = Data_Superstore[key_variable].var()
print(f'Variance of key variables of datasets are:\n {variance}')
# Out:
# Variance of key variables of datasets are:
#  Income               6.336838e+08
# Age                  1.436535e+02
# Recency              8.380071e+02
# Kidhome              2.882576e-01
# Teenhome             2.961332e-01
# MntWines             1.137901e+05
# MntFruits            1.583556e+03
# MntMeatProducts      5.030299e+04
# MntFishProducts      2.997791e+03
# NumDealsPurchases    3.700682e+00
# NumWebPurchases      7.512813e+00
# NumWebVisitsMonth    5.882364e+00
# dtype: float64

# %%
# 5 : Standard Deviation
key_variable = ['Income','Age','Recency','Kidhome','Teenhome','MntWines','MntFruits','MntMeatProducts','MntFishProducts','NumDealsPurchases','NumWebPurchases','NumWebVisitsMonth']
standard_deviation = Data_Superstore[key_variable].std()
print(f'Standard deviation of key variables of datasets are:\n {standard_deviation}')
# Out:
# Standard deviation of key variables of datasets are:
#  Income               25173.076661
# Age                     11.985554
# Recency                 28.948352
# Kidhome                  0.536896
# Teenhome                 0.544181
# MntWines               337.327920
# MntFruits               39.793917
# MntMeatProducts        224.283273
# MntFishProducts         54.752082
# NumDealsPurchases        1.923716
# NumWebPurchases          2.740951
# NumWebVisitsMonth        2.425359
# dtype: float64

# %%
# Identify Outliers
import seaborn as sns

# Create boxplots for key variables
key_variables = ['Income', 'Age','Recency', 'MntWines', 'MntFruits', 'MntMeatProducts', 'MntFishProducts',
                 'NumDealsPurchases', 'MntGoldProds', 'NumWebPurchases', 'NumWebVisitsMonth']

for variable in key_variables:
    sns.boxplot(y=Data_Superstore[variable])
    plt.show()

# %% [markdown]
# ## Task 3 - Probability Distributions 🎲
#
# - **Identify variables that could follow specific probability distributions (e.g., Binomial, Normal). Calculate probabilities and expected values based on these distributions.**

# %% [markdown]
# **Deliverables**:
#
# - **Determination of suitable probability distributions for relevant variables and corresponding calculated probabilities and expected values.**:

# %%
# plot the distribution of the some numerical features
num_features = ['Income','Age','NumWebPurchases']
count = 1
plt.subplots(figsize=(18,12))
for feature in num_features:
  plt.subplot(2,2,count)
  sns.histplot(Data_Superstore[feature], bins=30, kde = True)
  plt.title(f"Distribution of the variable {feature}", fontsize=16)
  plt.xlabel(f"{feature}")
  plt.ylabel("Density")
  count += 1
# Out:
# <ipython-input-34-22f5513b09ab>:6: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(2,2,count)

# %%
from scipy.stats import norm

# Normal distribution for age



# Poisson distribution for NumWebPurchases

# %% [markdown]
# ## Task 4: Insights and Customer Segmentation 📈
#
# - **Explore relationships between customer characteristics and spending habits. Segment customers based on their behaviors and characteristics.**

# %% [markdown]
# **Deliverables**:
#
# - **Key insights regarding relationships between variables and distinct customer segments based on behaviors.**

# %% [markdown]
# #### RFM Model (Recency, Frequency and Monetary) Analysis
#
# Recency, frequency and monetary analysis can be done for individual customers as well with the help of id of customers and hence application of customer segmentation ml algorithm can also be implemented after the statistical analysis.
#
# Segmentation on top of Education & Marital status has been examined for RFM values.

# %%
# Making new column for total amount spent by adding other columns data.
Data_Superstore["Total_monetary"] = Data_Superstore[["MntWines","MntFruits","MntMeatProducts","MntFishProducts","MntSweetProducts","MntGoldProds"]].apply(sum,axis =1)

# %%
Data_Superstore["Total_monetary"]
# Out:
# 0       1190
# 1        577
# 2        251
# 3         11
# 4         91
#         ...
# 2235     689
# 2236      55
# 2237     309
# 2238    1383
# 2239    1078
# Name: Total_monetary, Length: 2216, dtype: int64

# %%
# Making new column for total frequency of orders by adding all count of orders.
Data_Superstore["Frequency_Orders"] = Data_Superstore[["NumDealsPurchases","NumWebPurchases","NumCatalogPurchases","NumStorePurchases","NumWebVisitsMonth"]].apply(sum,axis =1)

# %%
Data_Superstore["Frequency_Orders"]
# Out:
# 0       16
# 1       23
# 2       13
# 3       11
# 4       15
#         ..
# 2235    24
# 2236    13
# 2237    22
# 2238    23
# 2239    25
# Name: Frequency_Orders, Length: 2216, dtype: int64

# %%
# Education-Income Insights
plt.figure(figsize=(12, 6))
sns.boxplot(x='Education', y='Income', data=Data_Superstore)
plt.title('Income across Different Education Levels')
plt.ylim(0,200000)
plt.xlabel('Education Level')
plt.ylabel('Income')
plt.show()

# %%
# Education-Recency Insights
plt.figure(figsize=(12, 6))
sns.boxplot(x='Education', y='Recency', data=Data_Superstore)
plt.title('Recency across Different Education Levels')
plt.xlabel('Education Level')
plt.ylabel('Recency')
plt.show()

# %%
# Education-Frequency_Orders Insights
plt.figure(figsize=(12, 6))
sns.boxplot(x='Education', y='Frequency_Orders', data=Data_Superstore)
plt.title('Frequency_Orders across Different Education Levels')
plt.xlabel('Education Level')
plt.ylabel('Frequency_Orders')
plt.show()

# %%
# Education-Total_monetary Insights
plt.figure(figsize=(12, 6))
sns.boxplot(x='Education', y='Total_monetary', data=Data_Superstore)
plt.title('Spending Habits across Different Education Levels')
plt.xlabel('Education Level')
plt.ylabel('Total_monetary')
plt.show()

# %%
#Marital Status IncomeInsights
plt.figure(figsize=(12, 6))
sns.boxplot(x='Marital_Status', y='Income', data=Data_Superstore)
plt.title('Income across Different Marital_Status Levels')
plt.ylim(0,125000)
plt.xlabel('Marital_Status')
plt.ylabel('Income')
plt.show()

# %%
#Marital Status-Recency Based Insights
plt.figure(figsize=(12, 6))
sns.boxplot(x='Marital_Status', y='Recency', data=Data_Superstore)
plt.title('Recency across Different Marital_Status Levels')
plt.xlabel('Marital_Status')
plt.ylabel('Recency')
plt.show()

# %%
#Marital Status-Frequency_Orders Insights
plt.figure(figsize=(12, 6))
sns.boxplot(x='Marital_Status', y='Frequency_Orders', data=Data_Superstore)
plt.title('Frequency_Orders across Different Marital_Status Levels')
plt.xlabel('Marital_Status')
plt.ylabel('Frequency_Orders')
plt.show()

# %%
#Marital Status-Total_monetary Insights
plt.figure(figsize=(12, 6))
sns.boxplot(x='Marital_Status', y='Total_monetary', data=Data_Superstore)
plt.title('Spending Habits across Different Marital Statuses')
plt.xlabel('Marital Status')
plt.ylabel('Total Spending')
plt.show()

# %% [markdown]
# ## Task 5: Conclusion and Recommendations
#
# - **Create clear visualizations to showcase your findings. Use insights to make recommendations for the company based on your analysis.**

# %% [markdown]
# **Deliverables**:
#
# - **Well-designed visualizations that visually represent your insights and actionable recommendations based on customer behavior analysis.**

# %%
# Relationship between Income & Total Spending
plt.figure(figsize=(8, 4))
sns.scatterplot(x='Income', y='Total_monetary', data=Data_Superstore)
plt.title('Relationship between Income and Total Spending')
plt.xlabel('Income')
plt.ylabel('Total Spending')
plt.show()

# %%
# Relationship between Income & Frequency_Orders
plt.figure(figsize=(8, 4))
sns.scatterplot(x='Income', y='Frequency_Orders', data=Data_Superstore)
plt.title('Relationship between Income and Frequency_Orders')
plt.xlabel('Income')
plt.ylabel('Frequency_Orders')
plt.show()

# %%
# Getting the columns that have int or float datatype
Data_Superstore_int = Data_Superstore[['Id','Age','Income','Kidhome','Teenhome',"Recency","Frequency_Orders","Total_monetary","MntWines","MntFruits","MntMeatProducts","MntFishProducts","MntSweetProducts",
                 "MntGoldProds","NumDealsPurchases","NumWebPurchases","NumCatalogPurchases","NumStorePurchases","NumWebVisitsMonth"]]

# %%
# Calculate correlation matrix
correlation_matrix = Data_Superstore_int.corr()

# Visualize correlation matrix using a heatmap
plt.figure(figsize=(15, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# **Higher Income level** customers are more likely to buy more as can be seen from the visualization, having high co relation with num catalogue, total monetary, mntwine and meat shows the expenditure interest and buying channel preference for this segment and they are less likely to visit website multiple times looking for deals.
#
# **Kidhome** segment that have kids are making very less purchases hence having negative correlation. But their website visits and deals_purchase have some positive relation showing that they keep looking for deals on the websites. Hence more deals related to kids and family can be marketed to them via website.
#
# **Frequency_orders**  having very high correlation with online purchases giving the insight that customers makes more orders online and on store purchases making many of the orders. And Wine orders being ordered most frequently.
#
# **Total_monetary** giving us the insight that catalogue and store purchases are giving high amount purchases and compared to web purchases. Meat and Wine being the highest contributor for these high amount purchases.
